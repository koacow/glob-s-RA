# %%
import pandas as pd
import os

# %%
import chardet
ACS_PATH = "/Users/koacow/BOSTON UNIVERSITY Dropbox/Ngoc Duy Khoa Cao/GLOB~S/Data/U.S. County Data/ACSDT5Y_2010_2022/raw"
# 1.1 Detect encoding of the file
ENCODING = 'utf-8'  # Default encoding
with open(os.path.join(ACS_PATH, "ACSDT5YB02001_2010_2022/ACSDT5Y2022.B02001-Data.csv"), 'rb') as file:
    result = chardet.detect(file.read())
    ENCODING = result['encoding']
ENCODING
# Out:
# 'UTF-8-SIG'

# %%
# 1.2 Load a sample file to check the structure
sample_file = os.path.join(ACS_PATH, "ACSDT5YB02001_2010_2022/ACSDT5Y2022.B02001-Data.csv")
sample_df = pd.read_csv(sample_file, encoding=ENCODING)
sample_df
# Out:
#               GEO_ID                              NAME       B02001_001E  \
# 0          Geography              Geographic Area Name  Estimate!!Total:
# 1     0500000US01001           Autauga County, Alabama             58761
# 2     0500000US01003           Baldwin County, Alabama            233420
# 3     0500000US01005           Barbour County, Alabama             24877
# 4     0500000US01007              Bibb County, Alabama             22251
# ...              ...                               ...               ...
# 3218  0500000US72145  Vega Baja Municipio, Puerto Rico             54182
# 3219  0500000US72147    Vieques Municipio, Puerto Rico              8199
# 3220  0500000US72149   Villalba Municipio, Puerto Rico             21984
# 3221  0500000US72151    Yabucoa Municipio, Puerto Rico             30313
# 3222  0500000US72153      Yauco Municipio, Puerto Rico             33988
#
#                   B02001_001M                    B02001_002E  \
# 0     Margin of Error!!Total:  Estimate!!Total:!!White alone
# 1                       *****                          43747
# 2                       *****                         195998
# 3                       *****                          11309
# 4                       *****                          16872
# ...                       ...                            ...
# 3218                    *****                          21954
# 3219                    *****                           1813
# 3220                    *****                           8732
# 3221                    *****                           2393
# 3222                    *****                          24982
#
#                                B02001_002M  \
# 0     Margin of Error!!Total:!!White alone
# 1                                      345
# 2                                     1247
# 3                                      221
# 4                                      225
# ...                                    ...
# 3218                                  1708
# 3219                                   622
# 3220                                  1041
# 3221                                   494
# 3222                                   808
#
#                                             B02001_003E  \
# 0     Estimate!!Total:!!Black or African American alone
# 1                                                 11496
# 2                                                 19445
# 3                                                 11668
# 4                                                  4603
# ...                                                 ...
# 3218                                               2444
# 3219                                                579
# 3220                                               1889
# 3221                                              11349
# 3222                                                916
#
#                                             B02001_003M  \
# 0     Margin of Error!!Total:!!Black or African Amer...
# 1                                                   525
# 2                                                   746
# 3                                                   220
# 4                                                   294
# ...                                                 ...
# 3218                                                629
# 3219                                                362
# 3220                                                553
# 3221                                               1294
# 3222                                                240
#
#                                             B02001_004E  \
# 0     Estimate!!Total:!!American Indian and Alaska N...
# 1                                                    59
# 2                                                   848
# 3                                                    74
# 4                                                    21
# ...                                                 ...
# 3218                                                  0
# 3219                                                  0
# 3220                                                 16
# 3221                                                  0
# 3222                                                 28
#
#                                             B02001_004M  ...  \
# 0     Margin of Error!!Total:!!American Indian and A...  ...
# 1                                                    71  ...
# 2                                                   325  ...
# 3                                                    39  ...
# 4                                                    25  ...
# ...                                                 ...  ...
# 3218                                                 35  ...
# 3219                                                 21  ...
# 3220                                                 25  ...
# 3221                                                 31  ...
# 3222                                                 31  ...
#
#                                             B02001_006M  \
# 0     Margin of Error!!Total:!!Native Hawaiian and O...
# 1                                                    30
# 2                                                    32
# 3                                                     4
# 4                                                    24
# ...                                                 ...
# 3218                                                 35
# 3219                                                 21
# 3220                                                 28
# 3221                                                 31
# 3222                                                 31
#
#                                   B02001_007E  \
# 0     Estimate!!Total:!!Some Other Race alone
# 1                                         321
# 2                                        4414
# 3                                        1088
# 4                                         108
# ...                                       ...
# 3218                                     9811
# 3219                                     5234
# 3220                                     2868
# 3221                                    15593
# 3222                                     5302
#
#                                          B02001_007M  \
# 0     Margin of Error!!Total:!!Some Other Race alone
# 1                                                243
# 2                                               1216
# 3                                                270
# 4                                                129
# ...                                              ...
# 3218                                            1288
# 3219                                             700
# 3220                                             680
# 3221                                            1301
# 3222                                             668
#
#                                B02001_008E  \
# 0     Estimate!!Total:!!Two or More Races:
# 1                                     2480
# 2                                    10638
# 3                                      609
# 4                                      578
# ...                                    ...
# 3218                                 19964
# 3219                                   557
# 3220                                  8479
# 3221                                   968
# 3222                                  2760
#
#                                       B02001_008M  \
# 0     Margin of Error!!Total:!!Two or More Races:
# 1                                             668
# 2                                            1169
# 3                                             215
# 4                                             321
# ...                                           ...
# 3218                                         1681
# 3219                                          359
# 3220                                         1140
# 3221                                          393
# 3222                                          529
#
#                                             B02001_009E  \
# 0     Estimate!!Total:!!Two or More Races:!!Two race...
# 1                                                   900
# 2                                                  3952
# 3                                                   195
# 4                                                   109
# ...                                                 ...
# 3218                                              19662
# 3219                                                549
# 3220                                               4846
# 3221                                                694
# 3222                                               2585
#
#                                             B02001_009M  \
# 0     Margin of Error!!Total:!!Two or More Races:!!T...
# 1                                                   372
# 2                                                   864
# 3                                                    97
# 4                                                   100
# ...                                                 ...
# 3218                                               1710
# 3219                                                353
# 3220                                                944
# 3221                                                347
# 3222                                                474
#
#                                             B02001_010E  \
# 0     Estimate!!Total:!!Two or More Races:!!Two race...
# 1                                                  1580
# 2                                                  6686
# 3                                                   414
# 4                                                   469
# ...                                                 ...
# 3218                                                302
# 3219                                                  8
# 3220                                               3633
# 3221                                                274
# 3222                                                175
#
#                                             B02001_010M Unnamed: 22
# 0     Margin of Error!!Total:!!Two or More Races:!!T...         NaN
# 1                                                   533         NaN
# 2                                                   874         NaN
# 3                                                   174         NaN
# 4                                                   310         NaN
# ...                                                 ...         ...
# 3218                                                147         NaN
# 3219                                                 18         NaN
# 3220                                                764         NaN
# 3221                                                168         NaN
# 3222                                                170         NaN
#
# [3223 rows x 23 columns]

# %%
from collections import defaultdict

B02001_dtypes = {
    "GEO_ID": "string",
    "NAME": "string",
    "B02001_001E": "Int64",
    "B02001_002E": "Int64",  
    "B02001_003E": "Int64",  
    "B02001_004E": "Int64",  
    "B02001_005E": "Int64",  
    "B02001_006E": "Int64", 
    "B02001_007E": "Int64",  
    "B02001_008E": "Int64",  
    "B02001_009E": "Int64", 
    "B02001_010E": "Int64",  
}
B02001_FULL = None
# 2.1 Load all B02001 files and concatenate them into a single DataFrame
for year in range(2010, 2023):
    file_path = os.path.join(ACS_PATH, f"ACSDT5YB02001_2010_2022/ACSDT5Y{year}.B02001-Data.csv")
    if os.path.exists(file_path):
        df = pd.read_csv(file_path, encoding=ENCODING, dtype=B02001_dtypes, skiprows=lambda x: x == 1)
        df = df.loc[1:, :] 
        df['year'] = year
        if B02001_FULL is None:
            B02001_FULL = df
        else:
            B02001_FULL = pd.concat([B02001_FULL, df], ignore_index=True)

B02001_FULL = B02001_FULL.drop(columns=['Unnamed: 22'])
B02001_FULL = B02001_FULL.rename(columns={
    "B02001_002E": "white_pop",
    "B02001_003E": "black_pop",
    "B02001_005E": "asian_pop",
    "NAME": "geographic_area_name",
    "GEO_ID": "FIPS5",
})
B02001_FULL = B02001_FULL[['FIPS5', 'geographic_area_name', 'year', 'white_pop', 'black_pop', 'asian_pop']]
B02001_FULL
# Out:
#                 FIPS5              geographic_area_name  year  white_pop  \
# 0      0500000US01003           Baldwin County, Alabama  2010     151453
# 1      0500000US01005           Barbour County, Alabama  2010      13759
# 2      0500000US01007              Bibb County, Alabama  2010      19038
# 3      0500000US01009            Blount County, Alabama  2010      53938
# 4      0500000US01011           Bullock County, Alabama  2010       2589
# ...               ...                               ...   ...        ...
# 41850  0500000US72145  Vega Baja Municipio, Puerto Rico  2022      21954
# 41851  0500000US72147    Vieques Municipio, Puerto Rico  2022       1813
# 41852  0500000US72149   Villalba Municipio, Puerto Rico  2022       8732
# 41853  0500000US72151    Yabucoa Municipio, Puerto Rico  2022       2393
# 41854  0500000US72153      Yauco Municipio, Puerto Rico  2022      24982
#
#        black_pop  asian_pop
# 0          16613       1149
# 1          12911         46
# 2           3450         36
# 3            716        246
# 4           8110         47
# ...          ...        ...
# 41850       2444          9
# 41851        579         16
# 41852       1889          0
# 41853      11349         10
# 41854        916          0
#
# [41855 rows x 6 columns]

# %%
B02001_FULL.isna().sum()
# Out:
# FIPS5                   0
# geographic_area_name    0
# year                    0
# white_pop               0
# black_pop               0
# asian_pop               0
# dtype: int64

# %%
B02001_FULL['year'].value_counts()
# Out:
# year
# 2022    3221
# 2010    3220
# 2011    3220
# 2012    3220
# 2013    3220
# 2020    3220
# 2021    3220
# 2014    3219
# 2015    3219
# 2016    3219
# 2017    3219
# 2018    3219
# 2019    3219
# Name: count, dtype: int64

# %%
# 2.2 Load all B19013 files and concatenate them into a single DataFrame
B19013_FULL = None
for year in range(2010, 2023):
    file_path = os.path.join(ACS_PATH, f"ACSDT5YB19013_2010_2022/ACSDT5Y{year}.B19013-Data.csv")
    if os.path.exists(file_path):
        df = pd.read_csv(file_path, encoding=ENCODING, skiprows=lambda x: x == 1)
        df['year'] = year
        if B19013_FULL is None:
            B19013_FULL = df
        else:
            B19013_FULL = pd.concat([B19013_FULL, df], ignore_index=True)
B19013_FULL = B19013_FULL.drop(columns=['Unnamed: 4'])
B19013_FULL = B19013_FULL.rename(columns={
    "B19013_001E": "median_household_income",
    "NAME": "geographic_area_name",
    "GEO_ID": "FIPS5"
})
B19013_FULL = B19013_FULL[['FIPS5', 'geographic_area_name', 'year', 'median_household_income']]
B19013_FULL
# Out:
#                 FIPS5              geographic_area_name  year  \
# 0      0500000US01001           Autauga County, Alabama  2010
# 1      0500000US01003           Baldwin County, Alabama  2010
# 2      0500000US01005           Barbour County, Alabama  2010
# 3      0500000US01007              Bibb County, Alabama  2010
# 4      0500000US01009            Blount County, Alabama  2010
# ...               ...                               ...   ...
# 41863  0500000US72145  Vega Baja Municipio, Puerto Rico  2022
# 41864  0500000US72147    Vieques Municipio, Puerto Rico  2022
# 41865  0500000US72149   Villalba Municipio, Puerto Rico  2022
# 41866  0500000US72151    Yabucoa Municipio, Puerto Rico  2022
# 41867  0500000US72153      Yauco Municipio, Puerto Rico  2022
#
#       median_household_income
# 0                     53255.0
# 1                     50147.0
# 2                     33219.0
# 3                     41770.0
# 4                     45549.0
# ...                       ...
# 41863                   23701
# 41864                   17062
# 41865                   22461
# 41866                   19972
# 41867                   19827
#
# [41868 rows x 4 columns]

# %%
B19013_FULL['year'].value_counts()
# Out:
# year
# 2022    3222
# 2010    3221
# 2011    3221
# 2012    3221
# 2013    3221
# 2020    3221
# 2021    3221
# 2014    3220
# 2015    3220
# 2016    3220
# 2017    3220
# 2018    3220
# 2019    3220
# Name: count, dtype: int64

# %%
B19013_FULL.isna().sum()
# Out:
# FIPS5                      0
# geographic_area_name       0
# year                       0
# median_household_income    2
# dtype: int64

# %%
# 2.3 Load all B01003 files and concatenate them into a single DataFrame
B01003_FULL = None
for year in range(2010, 2023):
    file_path = os.path.join(ACS_PATH, f"ACSDT5YB01003_2010_2022/ACSDT5Y{year}.B01003-Data.csv")
    if os.path.exists(file_path):
        df = pd.read_csv(file_path, encoding=ENCODING, dtype={
            "B01003_001E": "Int64",
        }, skiprows=lambda x: x == 1)
        df = df.loc[1:, :]
        df['year'] = year
        if B01003_FULL is None:
            B01003_FULL = df
        else:
            B01003_FULL = pd.concat([B01003_FULL, df], ignore_index=True)
B01003_FULL = B01003_FULL.drop(columns=['Unnamed: 4'])
B01003_FULL = B01003_FULL.rename(columns={
    "B01003_001E": "total_pop",
    "NAME": "geographic_area_name",
    "GEO_ID": "FIPS5"
})
B01003_FULL = B01003_FULL[['FIPS5', 'geographic_area_name', 'year', 'total_pop']]
B01003_FULL
# Out:
#                 FIPS5              geographic_area_name  year  total_pop
# 0      0500000US01003           Baldwin County, Alabama  2010     175791
# 1      0500000US01005           Barbour County, Alabama  2010      27699
# 2      0500000US01007              Bibb County, Alabama  2010      22610
# 3      0500000US01009            Blount County, Alabama  2010      56692
# 4      0500000US01011           Bullock County, Alabama  2010      10923
# ...               ...                               ...   ...        ...
# 41850  0500000US72145  Vega Baja Municipio, Puerto Rico  2022      54182
# 41851  0500000US72147    Vieques Municipio, Puerto Rico  2022       8199
# 41852  0500000US72149   Villalba Municipio, Puerto Rico  2022      21984
# 41853  0500000US72151    Yabucoa Municipio, Puerto Rico  2022      30313
# 41854  0500000US72153      Yauco Municipio, Puerto Rico  2022      33988
#
# [41855 rows x 4 columns]

# %%
B01003_FULL['year'].value_counts()
# Out:
# year
# 2022    3221
# 2010    3220
# 2011    3220
# 2012    3220
# 2013    3220
# 2020    3220
# 2021    3220
# 2014    3219
# 2015    3219
# 2016    3219
# 2017    3219
# 2018    3219
# 2019    3219
# Name: count, dtype: int64

# %%
# 3.1 Merge the three DataFrames on 'FIPS5' and 'year'
ACSDT5Y_FULL = B02001_FULL.merge(B19013_FULL, on=['FIPS5', 'year'], how='outer', suffixes=(None, '_y'))
ACSDT5Y_FULL = ACSDT5Y_FULL.drop(columns=[col for col in ACSDT5Y_FULL.columns if col.endswith('_y')])
ACSDT5Y_FULL = ACSDT5Y_FULL.merge(B01003_FULL, on=['FIPS5', 'year'], how='outer', suffixes=(None, '_y'))
ACSDT5Y_FULL =  ACSDT5Y_FULL.drop(columns=[col for col in ACSDT5Y_FULL.columns if col.endswith('_y')])

# 3.2 Calculate the 'other_pop' column
ACSDT5Y_FULL['other_pop'] = ACSDT5Y_FULL['total_pop'] - (ACSDT5Y_FULL['white_pop'] + ACSDT5Y_FULL['black_pop'] + ACSDT5Y_FULL['asian_pop'])
ACSDT5Y_FULL
# Out:
#                 FIPS5          geographic_area_name  year  white_pop  \
# 0      0500000US01001                          <NA>  2010       <NA>
# 1      0500000US01001                          <NA>  2011       <NA>
# 2      0500000US01001                          <NA>  2012       <NA>
# 3      0500000US01001                          <NA>  2013       <NA>
# 4      0500000US01001                          <NA>  2014       <NA>
# ...               ...                           ...   ...        ...
# 41863  0500000US72153  Yauco Municipio, Puerto Rico  2018      28189
# 41864  0500000US72153  Yauco Municipio, Puerto Rico  2019      26607
# 41865  0500000US72153  Yauco Municipio, Puerto Rico  2020      24931
# 41866  0500000US72153  Yauco Municipio, Puerto Rico  2021      24533
# 41867  0500000US72153  Yauco Municipio, Puerto Rico  2022      24982
#
#        black_pop  asian_pop median_household_income  total_pop  other_pop
# 0           <NA>       <NA>                 53255.0       <NA>       <NA>
# 1           <NA>       <NA>                 53899.0       <NA>       <NA>
# 2           <NA>       <NA>                 53773.0       <NA>       <NA>
# 3           <NA>       <NA>                 53682.0       <NA>       <NA>
# 4           <NA>       <NA>                 52475.0       <NA>       <NA>
# ...          ...        ...                     ...        ...        ...
# 41863       1300          5                 14954.0      36439       6945
# 41864       1346          6                 14743.0      35428       7469
# 41865       1244          5                   14813      34501       8321
# 41866       1282          0                   16444      34704       8889
# 41867        916          0                   19827      33988       8090
#
# [41868 rows x 9 columns]

# %%
# 3.3 Keep only the last 5 characters of the FIPS5 code
ACSDT5Y_FULL['FIPS5'] = ACSDT5Y_FULL['FIPS5'].str[-5:]
ACSDT5Y_FULL
# Out:
#        FIPS5          geographic_area_name  year  white_pop  black_pop  \
# 0      01001                          <NA>  2010       <NA>       <NA>
# 1      01001                          <NA>  2011       <NA>       <NA>
# 2      01001                          <NA>  2012       <NA>       <NA>
# 3      01001                          <NA>  2013       <NA>       <NA>
# 4      01001                          <NA>  2014       <NA>       <NA>
# ...      ...                           ...   ...        ...        ...
# 41863  72153  Yauco Municipio, Puerto Rico  2018      28189       1300
# 41864  72153  Yauco Municipio, Puerto Rico  2019      26607       1346
# 41865  72153  Yauco Municipio, Puerto Rico  2020      24931       1244
# 41866  72153  Yauco Municipio, Puerto Rico  2021      24533       1282
# 41867  72153  Yauco Municipio, Puerto Rico  2022      24982        916
#
#        asian_pop median_household_income  total_pop  other_pop
# 0           <NA>                 53255.0       <NA>       <NA>
# 1           <NA>                 53899.0       <NA>       <NA>
# 2           <NA>                 53773.0       <NA>       <NA>
# 3           <NA>                 53682.0       <NA>       <NA>
# 4           <NA>                 52475.0       <NA>       <NA>
# ...          ...                     ...        ...        ...
# 41863          5                 14954.0      36439       6945
# 41864          6                 14743.0      35428       7469
# 41865          5                   14813      34501       8321
# 41866          0                   16444      34704       8889
# 41867          0                   19827      33988       8090
#
# [41868 rows x 9 columns]

# %%
ACSDT5Y_FULL['year'].value_counts()
# Out:
# year
# 2022    3222
# 2010    3221
# 2011    3221
# 2012    3221
# 2013    3221
# 2020    3221
# 2021    3221
# 2014    3220
# 2015    3220
# 2016    3220
# 2017    3220
# 2018    3220
# 2019    3220
# Name: count, dtype: int64

# %%
ACSDT5Y_FULL.isna().sum()
# Out:
# FIPS5                       0
# geographic_area_name       13
# year                        0
# white_pop                  13
# black_pop                  13
# asian_pop                  13
# median_household_income     2
# total_pop                  13
# other_pop                  13
# dtype: int64

# %%
OUTPATH = "/Users/koacow/BOSTON UNIVERSITY Dropbox/Ngoc Duy Khoa Cao/GLOB~S/Data/U.S. County Data/ACSDT5Y_2010_2022/acs_2010_2022.csv"
ACSDT5Y_FULL.to_csv(OUTPATH, index=False, encoding=ENCODING)
