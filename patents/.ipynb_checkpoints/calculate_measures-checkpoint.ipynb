# %%
import dask.dataframe as dd

# %%
dtypes = {
    "patent_id": "string",
    "forward_citations": "int64",
}
fwd_citations = dd.read_csv("./data/final_fwdcitation.csv", dtype=dtypes)

fwd_citations.head()
# Out:
#   patent_id patent_type patent_date  \
# 0  10000000     utility  2018-06-19
# 1  10000001     utility  2018-06-19
# 2  10000002     utility  2018-06-19
# 3  10000003     utility  2018-06-19
# 4  10000004     utility  2018-06-19
#
#                                         patent_title wipo_kind  \
# 0  Coherent LADAR using intra-pixel quadrature de...        B2
# 1  Injection molding machine and mold thickness c...        B2
# 2  Method for manufacturing polymer film and co-e...        B2
# 3  Method for producing a container from a thermo...        B2
# 4  Process of obtaining a double-oriented film, c...        B2
#
#    forward_citations
# 0                 13
# 1                  0
# 2                  0
# 3                  2
# 4                  0

# %%
dtypes = {
    "patent_id": "string",
    "cpc_sequence": "int64",
}
cpc = dd.read_csv(
    "./data/g_cpc_current.tsv", 
    sep="\t",
    dtype=dtypes,
    )
cpc.head()
# Out:
#   patent_id  cpc_sequence cpc_section cpc_class cpc_subclass  cpc_group  \
# 0   3950000             0           A       A63         A63C  A63C9/001
# 1   3950000             1           A       A63         A63C   A63C9/00
# 2   3950000             2           A       A63         A63C  A63C9/002
# 3   3950000             3           A       A63         A63C  A63C9/081
# 4   3950001             0           A       A63         A63C  A63C9/086
#
#       cpc_type
# 0  inventional
# 1  inventional
# 2  inventional
# 3  inventional
# 4  inventional

# %%
citations_dtypes = {
    "patent_id": "string",
    "citation_patent_id": "string",
}
citations = dd.read_csv(
    "./data/g_us_patent_citation.tsv", 
    sep="\t",
    dtype=citations_dtypes,
    )
citations.head()
# Out:
#   patent_id  citation_sequence citation_patent_id citation_date record_name  \
# 0  10000000                  0            5093563    1992-03-01       Small
# 1  10000000                  1            5751830    1998-05-01  Hutchinson
# 2  10000001                  0            7804268    2010-09-01        Park
# 3  10000001                  1            9022767    2015-05-01        Oono
# 4  10000001                  2            9090016    2015-07-01    Takeuchi
#
#   wipo_kind   citation_category
# 0         A   cited by examiner
# 1         A  cited by applicant
# 2        B2   cited by examiner
# 3        B2   cited by examiner
# 4        B2   cited by examiner

# %%
fwd_citations = fwd_citations[["patent_id", "forward_citations"]]
cpc = cpc[["patent_id", "cpc_sequence", "cpc_group"]]
citations = citations[["patent_id", "citation_sequence", "citation_patent_id"]]

# %%
# Count the number of occurences of each unique pair of cpc_group accross all patents
from itertools import combinations
import os

# Step 1: Group by patent_id and collect all cpc_groups for each patent
# This will create a dataframe where each patent_id maps to a list of its cpc_groups
cpc_groups = cpc.groupby("patent_id")["cpc_group"].apply(list, meta=('cpc_group', 'object'))

# %%
# Step 2: Generate all unique pairs of cpc_group for each patent
def generate_pairs(cpc_group_list):
    return list(combinations(sorted(cpc_group_list), 2))

pairs = []
if not os.path.exists("./data/cpc_group_pairs.csv"):
    pairs = cpc_groups.map(generate_pairs, meta=('pairs', 'object'))
    pairs.to_csv("./data/cpc_group_pairs.csv", single_file=True)
else:
    pairs = dd.read_csv("./data/cpc_group_pairs.csv", dtype={'pairs': 'object'})
pairs.head()
# Out:
# patent_id
# 10000025    [(B29C70/202, B29C70/30), (B29C70/202, B29K210...
# 10000066    [(B41J2/14274, B41J2/175), (B41J2/14274, B41J2...
# 10000072    [(B41J11/008, B41J2/01), (B41J11/008, B41J3/40...
# 10000096                                                   []
# 10000098    [(B60C23/0433, B60C23/044), (B60C23/0433, B60C...
# Name: cpc_group, dtype: object

# %%
# Step 3: Flatten the list of pairs into a DataFrame
pairs_df = pairs.explode().dropna().to_frame(name="pair")
pairs_df.head()
# Out:
#                                   pair
# patent_id
# 10000025       (B29C70/202, B29C70/30)
# 10000025   (B29C70/202, B29K2105/0881)
# 10000025   (B29C70/202, B29L2031/3076)
# 10000025   (B29C70/202, B29L2031/3085)
# 10000025    (B29C70/202, B32B2307/544)

# %%
# Step 4: Count occurrences of each unique pair
pair_counts = []
if not os.path.exists("./data/cpc_group_pair_counts.csv"):
    pair_counts = pairs_df.groupby("pair").size().compute()
    pair_counts.to_csv("./data/cpc_group_pair_counts.csv", single_file=True)
else:
    pair_counts = dd.read_csv("./data/cpc_group_pairs.csv", dtype={'pair': 'object'})

pair_counts.head()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[23], line 4
#       2 pair_counts = []
#       3 if not os.path.exists("./data/cpc_group_pair_counts.csv"):
# ----> 4     pair_counts = pairs_df.groupby("pair").size().compute()
#       5     pair_counts.to_csv("./data/cpc_group_pair_counts.csv", single_file=True)
#       6 else:
#
# File /opt/miniconda3/lib/python3.12/site-packages/dask/dataframe/dask_expr/_collection.py:489, in FrameBase.compute(self, fuse, concatenate, **kwargs)
#     487     out = out.repartition(npartitions=1)
#     488 out = out.optimize(fuse=fuse)
# --> 489 return DaskMethodsMixin.compute(out, **kwargs)
#
# File /opt/miniconda3/lib/python3.12/site-packages/dask/base.py:374, in DaskMethodsMixin.compute(self, **kwargs)
#     350 def compute(self, **kwargs):
#     351     """Compute this dask collection
#     352
#     353     This turns a lazy Dask collection into its in-memory equivalent.
#    (...)
#     372     dask.compute
#     373     """
# --> 374     (result,) = compute(self, traverse=False, **kwargs)
#     375     return result
#
# File /opt/miniconda3/lib/python3.12/site-packages/dask/base.py:662, in compute(traverse, optimize_graph, scheduler, get, *args, **kwargs)
#     659     postcomputes.append(x.__dask_postcompute__())
#     661 with shorten_traceback():
# --> 662     results = schedule(dsk, keys, **kwargs)
#     664 return repack([f(r, *a) for r, (f, a) in zip(results, postcomputes)])
#
# File /opt/miniconda3/lib/python3.12/queue.py:171, in Queue.get(self, block, timeout)
#     169 elif timeout is None:
#     170     while not self._qsize():
# --> 171         self.not_empty.wait()
#     172 elif timeout < 0:
#     173     raise ValueError("'timeout' must be a non-negative number")
#
# File /opt/miniconda3/lib/python3.12/threading.py:355, in Condition.wait(self, timeout)
#     353 try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     354     if timeout is None:
# --> 355         waiter.acquire()
#     356         gotit = True
#     357     else:
#
# KeyboardInterrupt:

# %%
pair_counts.head()
# Out:
#    patent_id                                          cpc_group
# 0   10000025  [('B29C70/202', 'B29C70/30'), ('B29C70/202', '...
# 1   10000066  [('B41J2/14274', 'B41J2/175'), ('B41J2/14274',...
# 2   10000072  [('B41J11/008', 'B41J2/01'), ('B41J11/008', 'B...
# 3   10000096                                                 []
# 4   10000098  [('B60C23/0433', 'B60C23/044'), ('B60C23/0433'...

# %%
# Step 5: Merge the pair counts with the original cpc dataframe

pairs_with_counts = pairs_df.merge(pair_counts.rename('count'), on='pair', how='left')
pairs_with_counts.head()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[20], line 3
#       1 # Step 5: Merge the pair counts with the original cpc dataframe
#       2 pairs_df.reset_index()
# ----> 3 pairs_with_counts = pairs_df.merge(pair_counts.rename('count'), on='pair', how='left')
#       4 pairs_with_counts.head()
#
# File /opt/miniconda3/lib/python3.12/site-packages/dask/dataframe/dask_expr/_collection.py:3272, in DataFrame.rename(self, index, columns)
#    3269 @derived_from(pd.DataFrame, ua_args=["index"])
#    3270 def rename(self, index=None, columns=None):
#    3271     if index is not None:
# -> 3272         raise ValueError("Cannot rename index.")
#    3273     return new_collection(expr.RenameFrame(self, columns=columns))
#
# ValueError: Cannot rename index.
