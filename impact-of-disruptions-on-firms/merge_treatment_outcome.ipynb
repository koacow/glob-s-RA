# %%
import pandas as pd
import os

treatment_df = pd.read_csv('/Users/koacow/BOSTON UNIVERSITY Dropbox/Ngoc Duy Khoa Cao/Climate Risk and Labor Market/RAIS data/firms and cities/ESTB/treated/firms_geolocated_treated.csv'
                           , dtype={'cnpj_cei': str})
treatment_df = treatment_df[['cnpj_cei', 'year', 'treated', 'treatment_count', 'total_deaths', 'total_damage']]
treatment_df
# Out:
# /var/folders/zx/x6hb1_p95p33hh3235qrnlqm0000gn/T/ipykernel_66369/3390317297.py:4: DtypeWarning: Columns (6,7,21,43) have mixed types. Specify dtype option on import or set low_memory=False.
#   treatment_df = pd.read_csv('/Users/koacow/BOSTON UNIVERSITY Dropbox/Ngoc Duy Khoa Cao/Climate Risk and Labor Market/RAIS data/firms and cities/ESTB/treated/firms_geolocated_treated.csv'
#               cnpj_cei  year  treated  treatment_count  total_deaths  \
# 0            118000110  2003        0                0        2511.0
# 1            518000125  2003        0                0        2511.0
# 2            885000129  2003        0                0        2511.0
# 3            935000178  2003        0                0        2511.0
# 4           1172000180  2003        0                0        2511.0
# ...                ...   ...      ...              ...           ...
# 491335  16099194000407  2017        0                0         504.0
# ...

# %%
outcome_df = pd.read_csv('/Users/koacow/BOSTON UNIVERSITY Dropbox/Ngoc Duy Khoa Cao/Climate Risk and Labor Market/RAIS data/firms and cities/ESTB/estb_variables_july312025.csv',
                            dtype={'cnpjcei': str})
outcome_df = outcome_df.rename(columns={'cnpjcei': 'cnpj_cei'})
outcome_df
# Out:
#               cnpj_cei  year  nu_contr  nu_contr_disab  nu_contr_white  \
# 0       00308668000109  2003        22               4              17
# 1       00619461000147  2003       110               1             108
# 2       00697509000135  2003        38               1              36
# 3       00730769000165  2003        74               0               6
# 4       00735882000133  2003        83               0              59
# ...                ...   ...       ...             ...             ...
# 978170  12147176000150  2017         2               0               1
# 978171  60202660000187  2017         1               0               1
# 978172  04283674000100  2017         1               0               1
# 978173  05808792002001  2017         1               0               1
# 978174  00626951000170  2017         1               1               0
#
#         nu_contr_female  nu_contr_highereduc  avg_wage_est  avg_wage_disab  \
# ...

# %%
treatment_outcome_df = treatment_df.merge(outcome_df, on=['cnpj_cei', 'year'], how='right', validate='1:1')
treatment_outcome_df
# Out:
#               cnpj_cei  year  treated  treatment_count  total_deaths  \
# 0       00308668000109  2003      NaN              NaN           NaN
# 1       00619461000147  2003      NaN              NaN           NaN
# 2       00697509000135  2003      NaN              NaN           NaN
# 3       00730769000165  2003      NaN              NaN           NaN
# 4       00735882000133  2003      NaN              NaN           NaN
# ...                ...   ...      ...              ...           ...
# 978170  12147176000150  2017      NaN              NaN           NaN
# 978171  60202660000187  2017      NaN              NaN           NaN
# 978172  04283674000100  2017      NaN              NaN           NaN
# 978173  05808792002001  2017      NaN              NaN           NaN
# 978174  00626951000170  2017      NaN              NaN           NaN
#
#         total_damage  nu_contr  nu_contr_disab  nu_contr_white  \
# 0                NaN        22               4              17
# ...

# %%
treatment_outcome_df['treated'] = treatment_outcome_df['treated'].fillna(0)

# %%
treatment_outcome_df.describe().T
# Out:
#                         count          mean           std     min  \
# year                 978175.0  2.010266e+03  4.205207e+00  2003.0
# treated              978175.0  1.396069e-02  1.173278e-01     0.0
# treatment_count      286506.0  8.502440e-02  4.953310e-01     0.0
# total_deaths         286506.0  6.946209e+02  9.395828e+02     3.0
# total_damage         286506.0  2.082249e+06  2.577011e+06     0.0
# nu_contr             978175.0  2.124086e+02  4.623176e+02     1.0
# nu_contr_disab       978175.0  3.259388e+00  2.837748e+01     0.0
# nu_contr_white       978175.0  1.171173e+02  2.792156e+02     0.0
# nu_contr_female      978175.0  7.414755e+01  2.270044e+02     0.0
# nu_contr_highereduc  978175.0  3.959771e+01  1.661986e+02     0.0
# avg_wage_est         978175.0  2.054502e+02  3.496850e+02     0.0
# avg_wage_disab       377475.0  1.775105e+02  3.541447e+02     0.0
# avg_wage_nondis      977052.0  2.062764e+02  3.527980e+02     0.0
# ...

# %%
treatment_outcome_df['treated'].value_counts(dropna=False, normalize=True)
# Out:
# treated
# 0.0    0.986039
# 1.0    0.013961
# Name: proportion, dtype: float64

# %%
treatment_outcome_df.to_csv('/Users/koacow/BOSTON UNIVERSITY Dropbox/Ngoc Duy Khoa Cao/Climate Risk and Labor Market/RAIS data/firms and cities/ESTB/treated/brazil_firms_panel_2003_2017.csv', index=False)
